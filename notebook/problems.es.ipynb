# %% [markdown]
# # Problemas de prueba de hipótesis

# %% [markdown]
# ## Ejercicio 1
#
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?
#
# Para sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %%
# We import stats and numpy.
from scipy import stats
import numpy as np

# We generate the arrays for the two diets.
diet_1_group = [2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5]
diet_2_group = [3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2]

# We will check if this is a null hipothesis or if it is valid.
p_value = stats.ttest_ind(diet_1_group, diet_2_group).pvalue
nivel_alpha = 0.05

if p_value<nivel_alpha:
  print('We reject the null hypothesis of equality.')
  print('There is significant evidence that one diet is more effective than the other.')
else:
  print('There is no significant evidence to reject the null hypothesis, and therefore, we cannot conclude that one diet is more effective than the other.')

# We will now compare the mean values of each array to determine which one is more effective.
mean_diet_1_group = np.mean(diet_1_group)
mean_diet_2_group = np.mean(diet_2_group)

print(f'''The average weight loss for diet 1 is {mean_diet_1_group}
The average weight loss for diet 2 is {mean_diet_2_group}''')
# Out:
# We reject the null hypothesis of equality.
# There is significant evidence that one diet is more effective than the other.
# The average weight loss for diet 1 is 2.542857142857143
# The average weight loss for diet 2 is 3.0285714285714285

# %% [markdown]
# ### CONCLUSIONS FOR THE EXERCISE:
#
# We set the alpha level at 0.05 to establish a threshold for statistical significance, aiming to determine if one diet was more effective than the other. Our analysis revealed a p-value below 0.05, allowing us to confirm that there is a significant difference in effectiveness between the two diets. By examining the mean values of the two groups, we found that Diet 2 is more effective in promoting weight loss on average.

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## Ejercicio 2
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %%
# WE CREATE THE ARRAYS

fertilizante_1 = [20,21,20,19,20]
fertilizante_2 = [22,21,23,22,21]
fertilizante_3 = [24,23,22,23,24]

# WE ARE GOING TO CHECK IF IT IS A NULL HYPOTHESIS BY APPLYING THE ANOVA TEST.
p_value_2 = stats.f_oneway(fertilizante_1,fertilizante_2,fertilizante_3).pvalue
alpha_value = 0.05

if p_value_2<alpha_value:
  print('We reject the null hypothesis of equality.')
  print('There is significant evidence that one fertilizer is more effective than the others.')
else:
  print('There is no significant evidence to reject the null hypothesis, and therefore, we cannot conclude that any fertilizer is more effective than the others.')

# WE WILL CHECK THE MEANS TO DETERMINE WHICH FERTILIZER IS MORE EFFECTIVE.
mean_fertilizante_1 = np.mean(fertilizante_1)
mean_fertilizante_2 = np.mean(fertilizante_2)
mean_fertilizante_3 = np.mean(fertilizante_3)

print(f'''The average Kg of corn for fertilizer 1 is {mean_fertilizante_1}
The average Kg of corn for fertilizer 2 is {mean_fertilizante_2}
The average Kg of corn for fertilizer 3 is {mean_fertilizante_3}''')

print(f'We conclude that the fertilizer 3 is the most effective due to delivering a higher ammount of corn on average.')
# Out:
# We reject the null hypothesis of equality.
# There is significant evidence that one fertilizer is more effective than the others.
# The average Kg of corn for fertilizer 1 is 20.0
# The average Kg of corn for fertilizer 2 is 21.8
# The average Kg of corn for fertilizer 3 is 23.2
# We conclude that the fertilizer 3 is the most effective due to delivering a higher ammount of corn on average.

# %% [markdown]
# ### CONCLUSIONS FOR THE EXERCISE:
#
# We set the alpha level at 0.05 to establish a threshold for statistical significance, aiming to determine if one fertilizer was more effective than the others. Our analysis revealed a p-value below 0.05, allowing us to confirm that there is a significant difference in effectiveness between the two diets. By examining the mean values of the three groups, we found that Fertilizer 3 is the most effective one on average.
